# %% [markdown]
# # Vector Fields

# %%
import numpy as np
import matplotlib.pyplot as plt
# we'll need Matrix, UGrid, and Interpolator
from etraj.etraj import Vector, Matrix, UGrid, Interpolator, ScalarField, VectorField
import etraj.etraj as et

# %%
# create a uniformly random one-dimensional grid
# between -5 and 5 with N = 10000 points.
N = 10000
x = np.random.uniform(-5,5,N)

# next, create the grid of microstates for this 
# set of points.
g = UGrid(x)

# %% [markdown]
# ## Constructors

# %%
# Basic constructor
V = VectorField()
