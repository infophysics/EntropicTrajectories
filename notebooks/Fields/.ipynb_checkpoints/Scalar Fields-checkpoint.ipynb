# %% [markdown]
# # Scalar Fields

# %% [markdown]
# The scalar fields class essentially implements class for functions over some $d$-dimensional vector space $\mathbb{R}^d$.  In physics these are scalar fields, which we want to study the dynamics of.  The scalar fields class implements a large suite of useful operations including various methods for approximating derivatives and integrals, computing topological invariants, imposing a dynamics and the algebra of functions.
#
# A scalar field $\phi(x)$ is a function over some $d$-dimensional vector space $\mathbf{X} \subseteq \mathbb{R}^d$, whose points are written as $x \in \mathbf{X}$.  For most practical purposes, it is assumed that the scalar fields we are interested in belong to the subset of smooth functions over $\mathbf{X}$, i.e. $\phi(x) \in \Phi \subseteq C^{\infty}(\mathbf{X})$.

# %%
import numpy as np
import matplotlib.pyplot as plt
# we'll need Matrix, UGrid, and Interpolator
from etraj import Vector, Matrix, UGrid, Interpolator, ScalarField
import etraj

# %% [markdown]
# We can see what the various methods are that are available from Grid by printing out some of its contents using \__dir\__,

# %%
# grab the attributes of Grid
attributes = dir(ScalarField)
attributes = [a for a in attributes if a[0] != "_"]

# print the ones which are not built in
print("#: function")
print("++++++++++++++++++")
for i in range(len(attributes)):
    print("%s: %s()" % (i+1,attributes[i]))
# Out:
# #: function
# ++++++++++++++++++
# 1: DiffEQ()
# 2: Grid()
# 3: Integrator()
# 4: Interpolator()
# 5: N()
# 6: access_field()
# 7: construct_local_field_values()
# 8: data()
# 9: dim()
# 10: flag()
# 11: get_DiffEQ()
# 12: get_Grid()
# 13: get_Integrator()
# 14: get_Inteprolator()
# 15: get_N()
# 16: get_dim()
# 17: get_field()
# 18: get_flag()
# 19: get_info()
# 20: get_log()
# 21: get_name()
# 22: info()
# 23: log()
# 24: log_output()
# 25: name()
# 26: set_DiffEQ()
# 27: set_Grid()
# 28: set_Integrator()
# 29: set_Interpolator()
# 30: set_N()
# 31: set_dim()
# 32: set_field()
# 33: set_flag()
# 34: set_info()
# 35: set_log()
# 36: set_name()

# %% [markdown]
# ## Constructors

# %%
# Basic constructor
S = ScalarField()

# summary information
print(S)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# <etraj.ScalarField<double> ref at 0x558c7f9c78d0>
# ---------------------------------------------------
# <ET::ScalarField<double> object at 0x558c7f9c78d0>
# ---------------------------------------------------
#    name: 'default'
#     dim: 1
#       N: 0
# ---------------------------------------------------
#         Grid at: 0x558c80568ff0,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
# Interpolator at: 0x558c8056c6f0,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#       DiffEQ at: 0x558c8056b060,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#   Integrator at: 0x558c8029b4d0,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#       Logger at: 0x558c805638c0,
#          ref at: 0x7fffefb1cb40
# ++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# Constructor with a UGrid
# create a uniformly random one-dimensional grid
# between -5 and 5 with N = 10000 points.
N = 500
x = [[np.random.uniform(-2*np.pi,2*np.pi,1)[0]] for i in range(N)]

# next, create the grid of microstates for this 
# set of points.
g = UGrid(x)

S = ScalarField(g,g.log)
print(g)
print(S)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# <etraj.UGrid<double> ref at 0x558c802dd510>
# ---------------------------------------------------
# <ET::UGrid<double> object at 0x558c802dd510>
# ---------------------------------------------------
#    name: 'default'
#     dim: 1
#       N: 500
# ---------------------------------------------------
#  KDTree at: 0x7fffefb1cc50,
# ---------------------------------------------------
#  Logger at: 0x558c7fb02ef0,
#     ref at: 0x7fffefb1cbe0
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# <etraj.ScalarField<double> ref at 0x558c7f9b8c70>
# ---------------------------------------------------
# <ET::ScalarField<double> object at 0x558c7f9b8c70>
# ---------------------------------------------------
#    name: 'default'
#     dim: 1
#       N: 500
# ---------------------------------------------------
#         Grid at: 0x558c802dd510,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
# Interpolator at: 0x558c7f9ffce0,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#       DiffEQ at: 0x558c80577e30,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#   Integrator at: 0x558c805840b0,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#       Logger at: 0x558c7fb02ef0,
#          ref at: 0x7fffefb1cb40
# ++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# Constructor with UGrid and field values
f = np.cos(x)

S = ScalarField(name='f(x) = cos(x)',Grid=g,field=f)
print(S)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# <etraj.ScalarField<double> ref at 0x558c7f9c78d0>
# ---------------------------------------------------
# <ET::ScalarField<double> object at 0x558c7f9c78d0>
# ---------------------------------------------------
#    name: 'f(x) = cos(x)'
#     dim: 1
#       N: 500
# ---------------------------------------------------
#         Grid at: 0x558c802dd510,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
# Interpolator at: 0x558c80568ff0,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#       DiffEQ at: 0x558c8056b060,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#   Integrator at: 0x558c8029b4d0,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#       Logger at: 0x558c805638c0,
#          ref at: 0x7fffefb1cb40
# ++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## Attributes for scalar fields

# %%
#

# %% [markdown]
# ## The algebra of functions

# %% [markdown]
# The ScalarField class comes equipped with an assortment of operator overloads.  These include the standard addition and multiplication of two fields, as well as addition and multiplication by scalars.  The following gives some examples of the use of these operators.
#
# Let's first take a look at a set of one-dimensional examples.

# %%
# Adding two scalar fields

# Two scalar fields over the same grid can be added
S1 = ScalarField('cos(x)',np.cos(x),g)
S2 = ScalarField('sin(x)',np.sin(x),g)

f1 = S1.get_field()
f2 = S2.get_field()

# Let's see what these two fields look like
fig,axs = plt.subplots(figsize=(12,7))
axs.scatter(x,f1,color='c',label=r'$f1(x)=cos(x)$')
axs.scatter(x,f2,color='m',label=r'$f2(x)=sin(x)$')
axs.set_xlabel('x')
axs.set_ylabel('f(x)')
plt.legend()
plt.show()

# %%
# Now let's add the two fields together
S3 = S1 + S2
print(S3)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# <etraj.ScalarField<double> ref at 0x558c7f8a4c00>
# ---------------------------------------------------
# <ET::ScalarField<double> object at 0x558c7f8a4c00>
# ---------------------------------------------------
#    name: 'default'
#     dim: 1
#       N: 500
# ---------------------------------------------------
#         Grid at: 0x558c802dd510,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
# Interpolator at: 0x558c806d48b0,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#       DiffEQ at: 0x558c807c1c90,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#   Integrator at: 0x558c807c1d50,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#       Logger at: 0x558c7f9f9eb0,
#          ref at: 0x7fffefb1cb40
# ++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# The result is
f3 = S3.get_field()

fig,axs = plt.subplots(figsize=(12,7))
axs.scatter(x,f1,color='c',label=S1.get_name())
axs.scatter(x,f2,color='m',label=S2.get_name())
axs.scatter(x,f3,color='g',label=S3.get_name())
axs.set_xlabel('x')
axs.set_ylabel('f(x)')
plt.legend()
plt.show()

# %%
# While it will not crash the program, manipulating 
# scalar fields with different underlying UGrids will lead
# to a warning and is not advised.
g1 = UGrid(x)
g2 = UGrid(x)

SG1 = ScalarField('SG1',np.cos(x),g1)
SG2 = ScalarField('SG2',np.sin(x),g2)

SG1 += SG2
print(SG1)
SG1.log_output()
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# <etraj.ScalarField<double> ref at 0x558c80897650>
# ---------------------------------------------------
# <ET::ScalarField<double> object at 0x558c80897650>
# ---------------------------------------------------
#    name: '(SG1 + SG2)'
#     dim: 1
#       N: 500
# ---------------------------------------------------
#         Grid at: 0x558c8023f8b0,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
# Interpolator at: 0x558c8076b860,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#       DiffEQ at: 0x558c807bf580,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#   Integrator at: 0x558c80632650,
#          ref at: 0x7fffefb1cb40
# ---------------------------------------------------
#       Logger at: 0x558c80840710,
#          ref at: 0x7fffefb1cb40
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-31a781a902ff> in <module>
#      10 SG1 += SG2
#      11 print(SG1)
# ---> 12 SG1.log_output()
#
# TypeError: log_output(): incompatible function arguments. The following argument types are supported:
#     1. (self: etraj.KDTree) -> None
#     2. (self: etraj.KDTree, arg0: int) -> None
#
# Invoked with: <etraj.ScalarField<double> named '(SG1 + SG2)'>

# %%
SG1.log_output()
# Out:
# [20:09:02] [trace] ET:ScalarField:SG2_0: Scalar Field 'SG2' created at location 0x5593c7f8a140
# [20:09:02] [trace] ET:ScalarField:SG2_0: Interpolator 'default' created at location 0x5593c7ff7040
# [20:09:02] [info] ET:ScalarField:SG2_0: Logger passed to Interpolator 'def[20:09[20:09:02] [warning] ET:ScalarField:SG1_0: UGrids for scalar fields SG1 and SG2 do not match
# 09:02] [trace] ET:ScalarField:SG2: Interpolator 'default' destroyed at location 0x5593c7e9ecf0

# %%
# Subtraction works in the same way
S4 = S1 - S2
print(S4)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# <etraj.ScalarField ref at 0x5593c7f7c240>
# ---------------------------------------------------
# <ET::ScalarField<double&> object at 0x7ffd2cb1d078>
# ---------------------------------------------------
#    name: '(cos(x) - sin(x))'
#     dim: 1
#       N: 500
# ---------------------------------------------------
# UGrid 'default' at: 0x5593c806c360,
#             ref at: 0x5593c7f7c2a0
# Interpolator at: 0x5593c7e9ecf0,
#          ref at: 0x5593c7f7c2b0
# Logger at: 0x5593c806c360,
#    ref at: 0x5593c7f7c2d0
# ++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# The result is
f4 = S4.get_field()

fig,axs = plt.subplots(figsize=(12,7))
axs.scatter(x,f1,color='c',label=S1.get_name())
axs.scatter(x,f2,color='m',label=S2.get_name())
axs.scatter(x,f3,color='g',label=S3.get_name())
axs.scatter(x,f4,color='y',label=S4.get_name())
axs.set_xlabel('x')
axs.set_ylabel('f(x)')
plt.legend()
plt.show()

# %%
# We can also multiply two scalar fields
S5 = S1 * S2
print(S5)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# <etraj.ScalarField ref at 0x5593c7f397d0>
# ---------------------------------------------------
# <ET::ScalarField<double&> object at 0x7ffd2cb1d078>
# ---------------------------------------------------
#    name: '(cos(x) * sin(x))'
#     dim: 1
#       N: 500
# ---------------------------------------------------
# UGrid 'default' at: 0x5593c806c360,
#             ref at: 0x5593c7f39830
# Interpolator at: 0x5593c7e9ed80,
#          ref at: 0x5593c7f39840
# Logger at: 0x5593c806c360,
#    ref at: 0x5593c7f39860
# ++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# The result is
f5 = S5.get_field()

fig,axs = plt.subplots(figsize=(12,7))
axs.scatter(x,f1,color='c',label=S1.get_name())
axs.scatter(x,f2,color='m',label=S2.get_name())
axs.scatter(x,f5,color='g',label=S5.get_name())
axs.set_xlabel('x')
axs.set_ylabel('f(x)')
plt.legend()
plt.show()

# %%
# We can also divide two scalar fields whenever
# their functional form does not cross f(x) = 0.
x = np.random.uniform(0,1,N)
g = UGrid(x)

SD1 = ScalarField('2.0',g,[2.0 for i in range(len(x))])
SD2 = ScalarField('exp(x)',g,np.exp(x))
SD3 = SD1 / SD2
print(SD3)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# <etraj.ScalarField ref at 0x5593c7edecb0>
# ---------------------------------------------------
# <ET::ScalarField<double&> object at 0x7ffd2cb1d078>
# ---------------------------------------------------
#    name: '(2.0 / exp(x))'
#     dim: 1
#       N: 500
# ---------------------------------------------------
# UGrid 'default' at: 0x5593c810b0a0,
#             ref at: 0x5593c7eded10
# Interpolator at: 0x5593c853a540,
#          ref at: 0x5593c7eded20
# Logger at: 0x5593c810b0a0,
#    ref at: 0x5593c7eded40
# ++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# The result is
fd1 = SD1.get_field()
fd2 = SD2.get_field()
fd3 = SD3.get_field()

fig,axs = plt.subplots(figsize=(12,7))
axs.scatter(x,fd1,color='c',label=SD1.get_name())
axs.scatter(x,fd2,color='m',label=SD2.get_name())
axs.scatter(x,fd3,color='g',label=SD3.get_name())
axs.set_xlabel('x')
axs.set_ylabel('f(x)')
plt.legend()
plt.show()

# %% [markdown]
# ## Calculus over scalar fields

# %% [markdown]
# ## Integration

# %%
# first import the integrator
from etraj.etraj import Integrator
fig,axs = plt.subplots(figsize=(10,7))
for i in range(100):
    SD2.get_integrator().scalar_RK4_step(g,SD2,0.1)
    if i % 10 == 0:
        axs.scatter(x,SD2.get_field())
