# %% [markdown]
# # Approximator

# %%
# Let's examine the various features of the approximator class
# needed packages
import numpy as np
import matplotlib.pyplot as plt

# import various classes
from etraj.etraj import Vector, Matrix, UGrid, Approximator, ScalarField, DynamicalSystem
from etraj.etraj import ApproxType

# %%
# There are several different types of approximation schemes
# which are enumerated in the approx_type enum,
mls = ApproxType(0)
print(mls.name,int(mls))
rbf = ApproxType(1)
print(rbf.name,int(rbf))
# Out:
# MLS 0
# RBF 1

# %%
# For MLS there are various LAPACK drivers one can use,
from etraj.etraj import LSDriver
# There are four main types
xgels = LSDriver.xGELS
xgelsy = LSDriver.xGELSY
xgelsd = LSDriver.xGELSD
xgelss = LSDriver.xGELSS

# %%
# Given an approximator, we can switch the various LSDrivers 
# operating under the hood of the MLS scheme
app = Approximator()
app.set_approx_type("MLS")
app.set_lsdriver("xGELSY")
print(app)
# Out:
# Approximator type: Moving least squares
# Least squares driver type: xGELSY
# Approximator parameters - k = 3
#                           n = 3

# %%
# Each approximation scheme has a set of associated parameters
# such as 'k', the number of nearest neighbors to use,
# or in the case of MLS, 'n', the power of the monomial expansion.
# We can adjust the parameters by calling
app.set_k(10)
app.set_n(5)
print(app)
# Out:
# Approximator type: Moving least squares
# Least squares driver type: xGELSY
# Approximator parameters - k = 10
#                           n = 5

# %%
app.output()
# Out:
# [19:08:13] [trace] ET:Approximator:default: Approximator 'default' created at location 0x556002df6a50
# [19:08:13] [info] ET:Approximator:default: Approximator default: ApproxType set to MLS
# [19:08:13] [info] ET:Approximator:default: Approximator default: LSDriver set to xGELSY
# [19:08:14] [info] ET:Approximator:default: Approximator default: k set to 10
# [19:08:14] [info] ET:Approximator:default: Approximator default: n set to 5

# %%
# Attempts to set the ApproxType to something other than
# what is allowed will result in an error
app.set_approx_type("MyPrecious")
app.set_lsdriver("MeHatesIt")

# %%
app.output(2)
# Out:
# [19:08:14] [error] ET:Approximator:default: Approximator default: Attempted to set ApproxType to MyPrecious which is not a valid type
# [19:08:14] [error] ET:Approximator:default: Approximator default: Attempted to set LSDriver to MeHatesIt which is not a valid type

# %%
# Trying to set parameters to undefined values will throw errors
app.set_k(-4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-40dd31c7a7b6> in <module>
#       1 # Trying to set parameters to undefined values will throw errors
# ----> 2 app.set_k(-4)
#
# ValueError: Invalid value -4 passed to Approximator::set_k
